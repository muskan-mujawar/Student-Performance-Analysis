# %%
import matplotlib.pyplot as plt
import pandas as pd
print("done")
# Out:
# done

# %%
df1 = pd.read_csv(r"C:\Users\Muskan\Downloads\student (1)\student-mat.csv" , sep=";")
df1
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
df1.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %% [markdown]
# No missing values found.
# Data is clean and ready for analysis.

# %%
df1.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 390    False
# 391    False
# 392    False
# 393    False
# 394    False
# Length: 395, dtype: bool

# %% [markdown]
# No major duplicate issues observed.

# %%
df2= pd.read_csv(r"C:\Users\Muskan\Downloads\student (1)\student-por.csv")
df2 = df2.replace('"', '', regex=True)
df2
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
df2.info()
df2 = df2.astype({'G1': int, 'G2': int, 'G3': int})
df2
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %%
df2.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean    16.744222    2.514638    2.306626    1.568567    1.930663    0.221880
# std      1.218138    1.134552    1.099931    0.748660    0.829510    0.593235
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     3.930663    3.180277    3.184900    1.502311    2.280431    3.536210
# ...

# %% [markdown]
# Converted grade columns into integer format for proper analysis.

# %%
df2.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 644    False
# 645    False
# 646    False
# 647    False
# 648    False
# Length: 649, dtype: bool

# %%
df2.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
#Average Final Grade
avg_final_grade = df1["G3"].mean()
avg_final_grade
# Out:
# np.float64(10.415189873417722)

# %% [markdown]
# Average final grade represents overall student performance.
# Indicates that most students are in the medium performance range.

# %%
#Students Scoring Above 15
score_above_15 = (df1["G3"] > 15).sum()
score_above_15
# Out:
# np.int64(40)

# %% [markdown]
# Only a small number of students score high marks.
# Shows that achieving top performance is relatively difficult.

# %%
#Gender-Based Performance
gender_based_perf_mat = df1.groupby('sex')['G3'].mean()
gender_based_perf_mat
# Out:
# sex
# F     9.966346
# M    10.914439
# Name: G3, dtype: float64

# %%
plt.bar(gender_based_perf_mat.index,gender_based_perf_mat.values)
plt.xlabel("Gender")
plt.ylabel("Grade")
plt.title("Male vs Female avg score")
plt.show()

# %% [markdown]
# Performance difference between genders is minor.
# Indicates a balanced academic environment.

# %%
#Study Time vs Performance
time_based_perf =df1.groupby('studytime')['G3'].mean()
time_based_perf
# Out:
# studytime
# 1    10.047619
# 2    10.171717
# 3    11.400000
# 4    11.259259
# Name: G3, dtype: float64

# %% [markdown]
# Students who study more tend to score better.
# Shows a positive relationship between effort and results.

# %%
#Age vs Performance
age_based_perf =df1.groupby('age')['G3'].mean()
age_based_perf
# Out:
# age
# 15    11.256098
# 16    11.028846
# 17    10.275510
# 18     9.548780
# 19     8.208333
# 20    14.000000
# 21     7.000000
# 22     8.000000
# Name: G3, dtype: float64

# %% [markdown]
# Performance varies slightly with age.
# Younger students may perform slightly better due to consistency.

# %%
internet_access = df1.groupby('internet')['G3'].mean()
internet_access
# Out:
# internet
# no      9.409091
# yes    10.617021
# Name: G3, dtype: float64

# %%
#Absences vs Performance (Correlation)
df2["absences"].corr(df1["G3"])
# Out:
# np.float64(-0.0736115585988161)

# %% [markdown]
# Negative correlation between absences and grades.
# More absences → lower performance.

# %%
top =(df1["G3"] >= 15).sum()
low =(df1["G3"] < 10).sum()

# %%
low.mean()
# Out:
# np.float64(130.0)

# %%
low.mean()
# Out:
# np.float64(130.0)

# %% [markdown]
# Few high performers vs more low performers.
# Indicates need for academic support systems.

# %%
df2["failures"].corr(df1["G3"])
# Out:
# np.float64(-0.13546093429174866)

# %%
df1["G1"].corr(df1["G3"])
df1["G2"].corr(df1["G3"])
# Out:
# np.float64(0.9048679892693011)

# %%
df2["absences"].corr(df2["G3"])
# Out:
# np.float64(-0.0913790564387561)

# %%
avg_final_grade = df2["G3"].mean()
avg_final_grade
# Out:
# np.float64(11.906009244992296)

# %%
score_above_15 = (df2["G3"] > 15).sum()
score_above_15
# Out:
# np.int64(82)

# %%
gender_based_perf = df2.groupby('sex')['G3'].mean()
gender_based_perf
# Out:
# sex
# F    12.253264
# M    11.406015
# Name: G3, dtype: float64

# %%
plt.bar(gender_based_perf.index,gender_based_perf.values)
plt.xlabel("Gender")
plt.ylabel("Grade")
plt.title("Male vs Female avg score")
plt.show()

# %%
#Is study time correlated with performance?
time_based_perf =df2.groupby('studytime')['G3'].mean()
time_based_perf
# Out:
# studytime
# 1    10.844340
# 2    12.091803
# 3    13.226804
# 4    13.057143
# Name: G3, dtype: float64

# %%
age_based_perf =df.groupby('age')['G3'].mean()
age_based_perf
# Out:
# age
# 15    12.107143
# 16    11.994350
# 17    12.268156
# 18    11.771429
# 19     9.531250
# 20    12.000000
# 21    11.000000
# 22     5.000000
# Name: G3, dtype: float64

# %%
internet_access = df2.groupby('internet')['G3'].mean()
internet_access
# Out:
# internet
# no     11.026490
# yes    12.172691
# Name: G3, dtype: float64

# %%
df2["absences"].corr(df2["G3"])
# Out:
# np.float64(-0.0913790564387561)

# %%
top =(df2["G3"] >= 15).sum()
low =(df2["G3"] < 10).sum()

# %%
top.mean()
# Out:
# np.float64(131.0)

# %%
low.mean()
# Out:
# np.float64(100.0)

# %%
df2["failures"].corr(df2["G3"])
# Out:
# np.float64(-0.3933155480419928)

# %%
df2["G1"].corr(df2["G3"])
df2["G2"].corr(df2["G3"])
# Out:
# np.float64(0.9185480035603513)

# %%
plt.hist(df2["G1"], alpha=0.5, label="G1")
plt.hist(df2["G2"], alpha=0.5, label="G2")
plt.hist(df2["G3"], alpha=0.5, label="G3")

plt.legend()
plt.title("Grade Distribution Comparison")
plt.show()

# %%
import numpy as np
jitter_x = np.random.normal(0, 0.1, size=len(df2))
jitter_y = np.random.normal(0, 0.2, size=len(df2))
plt.scatter(df2['studytime'] + jitter_x,df2['G3'] + jitter_y)
plt.xlabel("studytime")
plt.ylabel("grade")
plt.title("studytime vs grade")
plt.show()

# %% [markdown]
# 📌 Majority of students fall in the average performance category
# 📌 Study time directly impacts performance → encourage disciplined study
#  Absenteeism negatively affects results → attendance monitoring needed
# Internet access improves learning outcomes → promote digital learning
#  Gender does not significantly affect performance → equal opportunities
# Low number of top scorers → need for advanced learning programs
